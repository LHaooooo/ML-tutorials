# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.datasets import load_boston
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
boston = load_boston()
# print(boston.keys())
print(boston['feature_names'])
print(boston['data'].shape, type(boston['data']))
print(boston['target'].shape, type(boston['target']))
df = pd.DataFrame(data = boston.data, columns =  boston['feature_names'])
print(df.head())
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']
# (506, 13) <class 'numpy.ndarray'>
# (506,) <class 'numpy.ndarray'>
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
# graph details analytics per selected feature
sns.set(style='whitegrid', context='notebook') 
cols = ['CRIM','ZN','INDUS','CHAS']
sns.pairplot(df[cols], size=2.5) 
plt.tight_layout()
plt.show()
# Out:
# /Users/liuhao/opt/miniconda3/envs/myenv/lib/python3.7/site-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# graph details analytics per selected feature
cm = np.corrcoef(df[cols].values.T) 
sns.set(font_scale=1.5)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 15}, yticklabels=cols, xticklabels=cols)
plt.tight_layout() 
plt.show()
sns.reset_orig()
